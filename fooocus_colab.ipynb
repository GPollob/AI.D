# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 10, in <module>
#     import modules.async_worker as worker
#   File "/content/Fooocus/modules/async_worker.py", line 3, in <module>
#     from extras.inpaint_mask import generate_mask_from_image, SAMOptions
#   File "/content/Fooocus/extras/inpaint_mask.py", line 6, in <module>
# ...

# %%
# prompt: {
#   "cells": [
#     {
#       "cell_type": "code",
#       "execution_count": 2,
#       "metadata": {
#         "id": "VjYy0F2gZIPR",
#         "outputId": "68d684f8-5a16-45a9-f95f-40c9dd35605a",
#         "colab": {
#           "base_uri": "https://localhost:8080/"
#         }
#       },
#       "outputs": [
#         {
#           "output_type": "stream",
#           "name": "stdout",
#           "text": [
#             "Requirement already satisfied: pygit2==1.15.1 in /usr/local/lib/python3.11/dist-packages (1.15.1)\n",
#             "Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)\n",
#             "Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)\n",
#             "/content\n",
#             "fatal: destination path 'Fooocus' already exists and is not an empty directory.\n",
#             "/content/Fooocus\n",
#             "Already up-to-date\n",
#             "Update succeeded.\n",
#             "[System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']\n",
#             "Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]\n",
#             "Fooocus version: 2.5.5\n",
#             "[Cleanup] Attempting to delete content of temp dir /tmp/fooocus\n",
#             "[Cleanup] Cleanup successful\n",
#             "Traceback (most recent call last):\n",
#             "  File \"/content/Fooocus/entry_with_update.py\", line 46, in <module>\n",
#             "    from launch import *\n",
#             "  File \"/content/Fooocus/launch.py\", line 152, in <module>\n",
#             "    from webui import *\n",
#             "  File \"/content/Fooocus/webui.py\", line 10, in <module>\n",
#             "    import modules.async_worker as worker\n",
#             "  File \"/content/Fooocus/modules/async_worker.py\", line 3, in <module>\n",
#             "    from extras.inpaint_mask import generate_mask_from_image, SAMOptions\n",
#             "  File \"/content/Fooocus/extras/i

npaint_mask.py\", line 5, in <module>\n",
            "    import modules.shared as shared\n",
            "ModuleNotFoundError: No module named 'modules.shared'\n"
          ]
        },
        {
          "output_type": "error",
          "ename": "ModuleNotFoundError",
          "evalue": "No module named 'modules.shared'",
          "traceback": [
            "\n",
            "---------------------------------------------------------------------------\n",
            "ModuleNotFoundError                       Traceback (most recent call last)\n",
            "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, **kw)\n",
            "   1477             self.showtraceback(running_compiled_code, \n",
            "   1478                             tb_offset=tb_offset,\n",
            "-> 1479                             exception_only=exception_only)\n",
            "   1480         else:\n",
            "   1481             if exception_only and not (isinstance(e, SyntaxError) and not e.text):\n",
            "\n",
            "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in showtraceback(self, *args, **kwargs)\n",
            "    1013         if tb_offset:\n",
            "    1014             self.tb_offset = tb_offset\n",
            "-> 1015         return VerboseTB.showtraceback(self, *args, **kwargs)\n",
            "    1016 \n",
            "    1017     def showsyntaxerror(self, filename=None, tb_offset=None, **kwargs):\n",
            "\n",
            "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)\n",
            "    875         if running_compiled_code:\n",
            "    876             # For an exception thrown during compilation, print the line number\n",
            "--> 877             self.print_exception(*exc_tuple)\n",
            "    878             return\n",
            "    879         \n",
            "\n",
            "/usr/local/lib/python3.11/dist-packages/IPython/core/ultratb.py in print_exception(self, etype, value, tb, tb_offset)\n",
            "    997         # Remove extra frames from the traceback:\n",
            "    998         if tb_offset and tb:\n",
            "--> 999             tb = tb.tb_next\n",
            "   1000             tb_offset -= 1\n",
            "   1001             \n",
            "\n",
            "/content/Fooocus/entry_with_update.py in <module>\n",
            "     44     os.environ[\"PYTHONPATH\"] = \".\"\n",
            "     45     from modules import shared\n",
            "---> 46     from launch import *\n",
            "     47     from modules import script_callbacks\n",
            "     48     script_callbacks.on_ui_settings()\n",
            "\n",
            "/content/Fooocus/launch.py in <module>\n",
            "    150     from modules import shared as shared\n",
            "    151     from modules import ui_extra_networks\n",
            "--> 152     from webui import *\n",
            "    153     \n",
            "    154     # set initial sd_model_checkpoint\n",
            "\n",
            "/content/Fooocus/webui.py in <module>\n",
            "      8     import gradio as gr\n",
            "      9     \n",
            "---> 10     import modules.async_worker as worker\n",
            "     11     from modules import ui, sd_models, shared, images, script_callbacks, sd_samplers, extra_networks, localization\n",
            "     12     from modules.call_queue import wrap_queued_call\n",
            "\n",
            "/content/Fooocus/modules/async_worker.py in <module>\n",
            "      1     import gc\n",
            "      2     \n",
            "----> 3     from extras.inpaint_mask import generate_mask_from_image, SAMOptions\n",
            "      4     from extras.roop import roop_process, roop_face_detect\n",
            "      5     import modules.shared as shared\n",
            "\n",
            "/content/Fooocus/extras/inpaint_mask.py in <module>\n",
            "      3     from PIL import Image\n",
            "      4     import numpy as np\n",
            "----> 5     import modules.shared as shared\n",
            "      6     import modules.sd_samplers\n",
            "      7     \n",
            "\n",
            "ModuleNotFoundError: No module named 'modules.shared'\n"
          ]
        }
      ],
      "source": [
        "!pip install pygit2==1.15.1\n",
        "%cd /content\n",
        "!git clone https://github.com/lllyasviel/Fooocus.git\n",
        "%cd /content/Fooocus\n",
        "!python entry_with_update.py --share --always-high-vram"
      ]
    }
  ],
  "metadata": {
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 0
}
# Out:
#   File "<tokenize>", line 45
#     ]
#     ^
# IndentationError: unindent does not match any outer indentation level
